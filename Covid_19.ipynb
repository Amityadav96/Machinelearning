# %% [markdown]
# <a href="https://colab.research.google.com/github/Amityadav96/Machinelearning/blob/main/Covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Grip spark foundation
# ##Timeline Analysis : Covid-19

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f03a6af1-876c-4927-bba5-0b3f66871f61" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f03a6af1-876c-4927-bba5-0b3f66871f61">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving owid-covid-data.csv to owid-covid-data.csv

# %%
#Having a glance at some of the records
import io
data= pd.read_csv(io.BytesIO(uploaded["owid-covid-data.csv"]))

# %%
data.head()
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.511
# 1      AFG      Asia  ...           64.83                   0.511
# 2      AFG      Asia  ...           64.83                   0.511
# 3      AFG      Asia  ...           64.83                   0.511
# 4      AFG      Asia  ...           64.83                   0.511
#
# [5 rows x 59 columns]

# %%
#Looking at the shape
data.shape
# Out:
# (75807, 59)

# %%
data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
#Looking at the different locations
data["location"].value_counts()
# Out:
# Mexico                      443
# Argentina                   443
# Thailand                    440
# Peru                        431
# Taiwan                      428
#                            ...
# Greenland                    34
# Montserrat                   31
# Turks and Caicos Islands     30
# Falkland Islands             16
# Northern Cyprus               9
# Name: location, Length: 215, dtype: int64

# %%
#Checking if columns have null values
data.isna().any()
# Out:
# iso_code                                 False
# continent                                 True
# location                                 False
# date                                     False
# total_cases                               True
# new_cases                                 True
# new_cases_smoothed                        True
# total_deaths                              True
# new_deaths                                True
# new_deaths_smoothed                       True
# total_cases_per_million                   True
# new_cases_per_million                     True
# new_cases_smoothed_per_million            True
# total_deaths_per_million                  True
# new_deaths_per_million                    True
# new_deaths_smoothed_per_million           True
# reproduction_rate                         True
# icu_patients                              True
# icu_patients_per_million                  True
# hosp_patients                             True
# hosp_patients_per_million                 True
# weekly_icu_admissions                     True
# weekly_icu_admissions_per_million         True
# weekly_hosp_admissions                    True
# weekly_hosp_admissions_per_million        True
# new_tests                                 True
# total_tests                               True
# total_tests_per_thousand                  True
# new_tests_per_thousand                    True
# new_tests_smoothed                        True
# new_tests_smoothed_per_thousand           True
# positive_rate                             True
# tests_per_case                            True
# tests_units                               True
# total_vaccinations                        True
# people_vaccinated                         True
# people_fully_vaccinated                   True
# new_vaccinations                          True
# new_vaccinations_smoothed                 True
# total_vaccinations_per_hundred            True
# people_vaccinated_per_hundred             True
# people_fully_vaccinated_per_hundred       True
# new_vaccinations_smoothed_per_million     True
# stringency_index                          True
# population                                True
# population_density                        True
# median_age                                True
# aged_65_older                             True
# aged_70_older                             True
# gdp_per_capita                            True
# extreme_poverty                           True
# cardiovasc_death_rate                     True
# diabetes_prevalence                       True
# female_smokers                            True
# male_smokers                              True
# handwashing_facilities                    True
# hospital_beds_per_thousand                True
# life_expectancy                           True
# human_development_index                   True
# dtype: bool

# %%
#Getting the sum of null values across each column
data.isna().sum()
# Out:
# iso_code                                     0
# continent                                 3724
# location                                     0
# date                                         0
# total_cases                               1292
# new_cases                                 1294
# new_cases_smoothed                        2295
# total_deaths                             10561
# new_deaths                               10403
# new_deaths_smoothed                       2295
# total_cases_per_million                   1698
# new_cases_per_million                     1700
# new_cases_smoothed_per_million            2696
# total_deaths_per_million                 10954
# new_deaths_per_million                   10796
# new_deaths_smoothed_per_million           2696
# reproduction_rate                        14691
# icu_patients                             67877
# icu_patients_per_million                 67877
# hosp_patients                            66257
# hosp_patients_per_million                66257
# weekly_icu_admissions                    75110
# weekly_icu_admissions_per_million        75110
# weekly_hosp_admissions                   74583
# weekly_hosp_admissions_per_million       74583
# new_tests                                41229
# total_tests                              41457
# total_tests_per_thousand                 41457
# new_tests_per_thousand                   41229
# new_tests_smoothed                       36248
# new_tests_smoothed_per_thousand          36248
# positive_rate                            37543
# tests_per_case                           38154
# tests_units                              34901
# total_vaccinations                       71005
# people_vaccinated                        71493
# people_fully_vaccinated                  72919
# new_vaccinations                         71704
# new_vaccinations_smoothed                68594
# total_vaccinations_per_hundred           71005
# people_vaccinated_per_hundred            71493
# people_fully_vaccinated_per_hundred      72919
# new_vaccinations_smoothed_per_million    68594
# stringency_index                         10943
# population                                 415
# population_density                        5051
# median_age                                7064
# aged_65_older                             7854
# aged_70_older                             7451
# gdp_per_capita                            6827
# extreme_poverty                          28739
# cardiovasc_death_rate                     6211
# diabetes_prevalence                       5311
# female_smokers                           21118
# male_smokers                             21922
# handwashing_facilities                   40885
# hospital_beds_per_thousand               12131
# life_expectancy                           3779
# human_development_index                   6269
# dtype: int64

# %%
#Getting the cases in India
india_case=data[data["location"]=="India"]

# %%
india_case.head()
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 31110      IND      Asia  ...           69.66                   0.645
# 31111      IND      Asia  ...           69.66                   0.645
# 31112      IND      Asia  ...           69.66                   0.645
# 31113      IND      Asia  ...           69.66                   0.645
# 31114      IND      Asia  ...           69.66                   0.645
#
# [5 rows x 59 columns]

# %%
india_case.tail()

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#Total cases per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=india_case)
plt.show()

# %%
#Making a dataframe for last 5 days
india_last_5_days=india_case.tail()

# %%
#Total cases in last 5 days
sns.set(rc={'figure.figsize':(3,3)})
sns.lineplot(x="date",y="total_cases",data=india_last_5_days)
plt.show()

# %%
#Total tests per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests",data=india_case)
plt.show()

# %%
#Total tests in last 5 days
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests",data=india_last_5_days)
plt.show()

# %%
#Brazil Case
brazil_case=data[data["location"]=="Brazil"] 
brazil_case.head()
# Out:
#      iso_code      continent  ... life_expectancy human_development_index
# 9734      BRA  South America  ...           75.88                   0.765
# 9735      BRA  South America  ...           75.88                   0.765
# 9736      BRA  South America  ...           75.88                   0.765
# 9737      BRA  South America  ...           75.88                   0.765
# 9738      BRA  South America  ...           75.88                   0.765
#
# [5 rows x 59 columns]

# %%
brazil_case.tail()
# Out:
#       iso_code      continent  ... life_expectancy human_development_index
# 10116      BRA  South America  ...           75.88                   0.765
# 10117      BRA  South America  ...           75.88                   0.765
# 10118      BRA  South America  ...           75.88                   0.765
# 10119      BRA  South America  ...           75.88                   0.765
# 10120      BRA  South America  ...           75.88                   0.765
#
# [5 rows x 59 columns]

# %%
#Making a dataframe for brazil for last 5 days
brazil_last_5_days=brazil_case.tail()

# %%
#Total cases in last 5 days
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=brazil_last_5_days)
plt.show()

# %%
#Understanding cases of India, China and Japan
india_japan_china=data[(data["location"] =="India") | (data["location"] =="China") | (data["location"]=="Japan")]

# %%
#Plotting growth of cases across China, India and Japan
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="location",y="total_cases",data=india_japan_china,hue="date")
plt.show()

# %%
#Understanding cases of germany and spain
germany_spain=data[(data["location"] =="Germany") | (data["location"] =="Spain")]

# %%
#Plotting growth of cases across Germany and Spain
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="location",y="total_cases",data=germany_spain,hue="date")
plt.show()

# %%
#Getting latest data
last_day_cases=data[data["date"]=="2020-05-24"]
last_day_cases
# Out:
#        iso_code continent  ... life_expectancy human_development_index
# 90          AFG      Asia  ...           64.83                   0.511
# 490    OWID_AFR       NaN  ...             NaN                     NaN
# 878         ALB    Europe  ...           78.57                   0.795
# 1266        DZA    Africa  ...           76.88                   0.748
# 1648        AND    Europe  ...           83.73                   0.868
# ...         ...       ...  ...             ...                     ...
# 74013       VNM      Asia  ...           75.40                   0.704
# 74435  OWID_WRL       NaN  ...           72.58                   0.737
# 74778       YEM      Asia  ...           66.12                   0.470
# 75144       ZMB    Africa  ...           63.89                   0.584
# 75508       ZWE    Africa  ...           61.49                   0.571
#
# [194 rows x 59 columns]

# %%
#Sorting data w.r.t total_cases
max_cases_country=last_day_cases.sort_values(by="total_cases",ascending=False)
max_cases_country
# Out:
#        iso_code      continent  ... life_expectancy human_development_index
# 74435  OWID_WRL            NaN  ...           72.58                   0.737
# 49948  OWID_NAM            NaN  ...             NaN                     NaN
# 23162  OWID_EUR            NaN  ...             NaN                     NaN
# 71975       USA  North America  ...           78.86                   0.926
# 23583  OWID_EUN            NaN  ...             NaN                     NaN
# ...         ...            ...  ...             ...                     ...
# 73222       VAT         Europe  ...           75.12                     NaN
# 60105       SYC         Africa  ...           73.40                   0.796
# 65333       SUR  South America  ...           71.68                   0.738
# 53048       PNG        Oceania  ...           64.50                   0.555
# 38598       LSO         Africa  ...           54.33                   0.527
#
# [194 rows x 59 columns]

# %%
#Top 5 countries with maximum cases
max_cases_country[1:6]
# Out:
#        iso_code      continent  ... life_expectancy human_development_index
# 49948  OWID_NAM            NaN  ...             NaN                     NaN
# 23162  OWID_EUR            NaN  ...             NaN                     NaN
# 71975       USA  North America  ...           78.86                   0.926
# 23583  OWID_EUN            NaN  ...             NaN                     NaN
# 3669   OWID_ASI            NaN  ...             NaN                     NaN
#
# [5 rows x 59 columns]

# %%
#Making bar-plot for countries with top cases
sns.barplot(x="location",y="total_cases",data=max_cases_country[1:6],hue="location")
plt.show()

# %%
india_case.head()
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 31110      IND      Asia  ...           69.66                   0.645
# 31111      IND      Asia  ...           69.66                   0.645
# 31112      IND      Asia  ...           69.66                   0.645
# 31113      IND      Asia  ...           69.66                   0.645
# 31114      IND      Asia  ...           69.66                   0.645
#
# [5 rows x 59 columns]

# %%
#Linear regression
from sklearn.model_selection import train_test_split

# %%
#converting string date to date-time
import datetime as dt
india_case['date'] = pd.to_datetime(india_case['date']) 
india_case.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       iso_code continent  ... life_expectancy human_development_index
# 31110      IND      Asia  ...           69.66                   0.645
# 31111      IND      Asia  ...           69.66                   0.645
# 31112      IND      Asia  ...           69.66                   0.645
# 31113      IND      Asia  ...           69.66                   0.645
# 31114      IND      Asia  ...           69.66                   0.645
#
# [5 rows x 59 columns]

# %%
india_case.head()
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 31110      IND      Asia  ...           69.66                   0.645
# 31111      IND      Asia  ...           69.66                   0.645
# 31112      IND      Asia  ...           69.66                   0.645
# 31113      IND      Asia  ...           69.66                   0.645
# 31114      IND      Asia  ...           69.66                   0.645
#
# [5 rows x 59 columns]

# %%
#converting date-time to ordinal
india_case['date']=india_case['date'].map(dt.datetime.toordinal)
india_case.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       iso_code continent  ... life_expectancy  human_development_index
# 31110      IND      Asia  ...           69.66                    0.645
# 31111      IND      Asia  ...           69.66                    0.645
# 31112      IND      Asia  ...           69.66                    0.645
# 31113      IND      Asia  ...           69.66                    0.645
# 31114      IND      Asia  ...           69.66                    0.645
#
# [5 rows x 59 columns]

# %%
#getting dependent variable and inpedent variable
x=india_case['date']
y=india_case['total_cases']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
import numpy as np
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
india_case.tail()
# Out:
#       iso_code continent  ... life_expectancy  human_development_index
# 31519      IND      Asia  ...           69.66                    0.645
# 31520      IND      Asia  ...           69.66                    0.645
# 31521      IND      Asia  ...           69.66                    0.645
# 31522      IND      Asia  ...           69.66                    0.645
# 31523      IND      Asia  ...           69.66                    0.645
#
# [5 rows x 59 columns]

# %%
y_pred=lr.predict(np.array(x_test).reshape(-1,1))

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(x_test,y_pred)
# Out:
# 28107404952266.715

# %%
lr.predict(np.array([[737573]]))
# Out:
# array([[1450324.28937912]])
